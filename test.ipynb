# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('img2.jpg')
plt.imshow(img)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
s = hsv[:,:,1]
ret, s_threshold = cv2.threshold(s,,255,cv2.THRESH_BINARY)
plt.imshow(s_threshold, 'gray')

# %%
hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
s = hls[:,:,1]
plt.imshow(s)
# s_bin = np.logical_not(s_threshold).astype(int)
# s_bin = (s_bin*255).astype(np.uint8)
# plt.imshow(s_bin, 'gray')

# %%
hls[:, :, 1] = hls[:,:,1]+s_bin

# %%
new_img = img_gray+s_bin

# %%
plt.imshow(hls)

# %%
from PIL import Image

# %%
img1 = Image.open('img2.jpg')
img2 = Image.open('binary.jpg').convert(img1.mode)

# %%
Image.blend(img1, img2, 0.5).show()

# %%
cv2.imwrite('binary.jpg',s_bin)
# Out:
# True

# %%
b,g,r = cv2.split(img)
cv2.imshow('Blue Channel',b)
cv2.imshow('Green Channel',g)
cv2.imshow('Red Channel',r)
cv2.waitKey(0)
